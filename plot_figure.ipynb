# %% [markdown]
# ## plot scatter figure of height and weight

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# chinese font
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 坐标负号处理
plt.rcParams['axes.unicode_minus'] = False

# %%
#df = pd.read_csv('D:/Project/pan_qaidam_yardang/result/629/result_629.csv')
df = pd.read_csv('D:/Project/pan_qaidam_yardang/grid_analysis/merge_joinpoints.csv')

# %%
fig = plt.gcf()
#ax1 = fig.add_axes([0.07, 0.1, 0.35, 0.75])

plt.figure(figsize=(9,6))
plt.scatter(df.height, df.width,c='c', s=4, alpha= 0.4)





plt.show()

# %%
plt.scatter(df.AREA, df.ratio,c='c', s=4, alpha= 0.4)
